# %% [markdown]
# <h1 style="text-align: center; font-weight: bold;"><u>Étape 2 Analyse bi-variée</u></h1>

# %% [markdown]
# <h2 style="font-weight: bold;">2.A)<u>Histogramme</u></h2>

# %% [markdown]
# <h3 style="font-weight: bold;"><u>omega-3-fat_100g</u></h3>

# %%
# Importation des bibliothèques pandas et numpy
import pandas as pd
import numpy as np
from myFonctions import plot_histogram
from myFonctions import plot_scatter

# Lire le fichier CSV
nutritionalProducts = pd.read_csv("data/foodfacts.csv", sep="\t", encoding="utf-8", low_memory=False)
plot_histogram(nutritionalProducts, 'omega-3-fat_100g')

# %% [markdown]
# <h3 style="font-weight: bold;"><u>omega-6-fat_100g</u></h3>

# %%
# Importation des bibliothèques pandas et numpy
import pandas as pd
import numpy as np
from myFonctions import plot_histogram
from myFonctions import plot_scatter

# Lire le fichier CSV
nutritionalProducts = pd.read_csv("data/foodfacts.csv", sep="\t", encoding="utf-8", low_memory=False)
plot_histogram(nutritionalProducts, 'omega-6-fat_100g')

# %% [markdown]
# <h3 style="font-weight: bold;"><u>iron_100g</u></h3>

# %%
# Importation des bibliothèques pandas et numpy
import pandas as pd
import numpy as np
from myFonctions import plot_histogram
from myFonctions import plot_scatter

# Lire le fichier CSV
nutritionalProducts = pd.read_csv("data/foodfacts.csv", sep="\t", encoding="utf-8", low_memory=False)
plot_histogram(nutritionalProducts, 'iron_100g')

# %% [markdown]
# <h3 style="font-weight: bold;"><u>calcium_100g</u></h3>

# %%
# Importation des bibliothèques pandas et numpy
import pandas as pd
import numpy as np
from myFonctions import plot_histogram
from myFonctions import plot_scatter

# Lire le fichier CSV
nutritionalProducts = pd.read_csv("data/foodfacts.csv", sep="\t", encoding="utf-8", low_memory=False)
plot_histogram(nutritionalProducts, 'calcium_100g')

# %% [markdown]
# <h3 style="font-weight: bold;"><u>energy-from-fat_100g</u></h3>

# %%
# Importation des bibliothèques pandas et numpy
import pandas as pd
import numpy as np
from myFonctions import plot_histogram
from myFonctions import plot_scatter

# Lire le fichier CSV
nutritionalProducts = pd.read_csv("data/foodfacts.csv", sep="\t", encoding="utf-8", low_memory=False)
plot_histogram(nutritionalProducts, 'energy-from-fat_100g')

# %% [markdown]
# <h2 style="font-weight: bold;">2.B)<u>Nuage</u></h2>

# %% [markdown]
# <h3 style="font-weight: bold;"><u>Omega-3-fat_100g et Omega-6-fat_100g</u></h3>

# %%
# Importation des bibliothèques pandas et numpy
import pandas as pd
import numpy as np
from myFonctions import plot_histogram
from myFonctions import plot_scatter

# Lire le fichier CSV
nutritionalProducts = pd.read_csv("data/foodfacts.csv", sep="\t", encoding="utf-8", low_memory=False)

# Afficher un scatter plot entre 'omega-3-fat_100g' et 'omega-6-fat_100g'
plot_scatter(nutritionalProducts, 'omega-3-fat_100g', 'omega-6-fat_100g')

# %% [markdown]
# <h3 style="font-weight: bold;"><u>Omega-3-fat_100g et Energy-from-fat_100g</u></h3>

# %%
# Importation des bibliothèques pandas et numpy
import pandas as pd
import numpy as np
from myFonctions import plot_histogram
from myFonctions import plot_scatter

# Lire le fichier CSV
nutritionalProducts = pd.read_csv("data/foodfacts.csv", sep="\t", encoding="utf-8", low_memory=False)

# Afficher un scatter plot entre 'omega-3-fat_100g' et 'omega-6-fat_100g'
plot_scatter(nutritionalProducts, 'omega-3-fat_100g', 'energy-from-fat_100g')

# %% [markdown]
# <h3 style="font-weight: bold;"><u>Omega-6-fat_100g et Energy-from-fat_100g</u></h3>

# %%
# Importation des bibliothèques pandas et numpy
import pandas as pd
import numpy as np
from myFonctions import plot_histogram
from myFonctions import plot_scatter

# Lire le fichier CSV
nutritionalProducts = pd.read_csv("data/foodfacts.csv", sep="\t", encoding="utf-8", low_memory=False)

# Afficher un scatter plot entre 'omega-3-fat_100g' et 'omega-6-fat_100g'
plot_scatter(nutritionalProducts, 'iron_100g', 'energy-from-fat_100g')

# %% [markdown]
# <h3 style="font-weight: bold;"><u>Calcium_100g et Energy-from-fat_100g</u></h3>

# %%
# Importation des bibliothèques pandas et numpy
import pandas as pd
import numpy as np
from myFonctions import plot_histogram
from myFonctions import plot_scatter

# Lire le fichier CSV
nutritionalProducts = pd.read_csv("data/foodfacts.csv", sep="\t", encoding="utf-8", low_memory=False)

# Afficher un scatter plot entre 'omega-3-fat_100g' et 'omega-6-fat_100g'
plot_scatter(nutritionalProducts, 'calcium_100g', 'energy-from-fat_100g')

# %% [markdown]
# <h3 style="font-weight: bold;"><u>Iron_100g et Calcium_100g</u></h3>

# %%
# Importation des bibliothèques pandas et numpy
import pandas as pd
import numpy as np
from myFonctions import plot_histogram
from myFonctions import plot_scatter

# Lire le fichier CSV
nutritionalProducts = pd.read_csv("data/foodfacts.csv", sep="\t", encoding="utf-8", low_memory=False)

# Afficher un scatter plot entre 'omega-3-fat_100g' et 'omega-6-fat_100g'
plot_scatter(nutritionalProducts, 'iron_100g', 'calcium_100g')
